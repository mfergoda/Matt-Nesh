# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
# %matplotlib notebook

# %%
# Just testing stuff
NR = 99
R1 = 1.0
R2 = 10.0
r = np.linspace(R1,R2,NR)
f1 = 1.0
f2 = 2.0
D = 1.0
params = [r,f1,f2,D]

# Initial conditions
f0 = np.linspace(0.0,3.0,NR)

# %%
def dfdt(f,t,params): # Params is list of r values
    r = params[0]; # print r
    f1 = params[1]; # print f1
    f2 = params[2]; # print f2
    D = params[3]; 
    NR = len(f)
    
    finternal = np.append(f,f2)
    finternal = np.append(f1,finternal)
    # print finternal
    dr = r[1] - r[0]
    term1 = (finternal[2:]-finternal[1:-1]) / (dr * r)
    term2 = (finternal[0:-2] - 2*finternal[1:-1] + finternal[2:]) / (dr**2)
    
    return D*(term1 + term2)

# %%
# numerical solution
tinterval = [0.0,500.0]
f = odeint(dfdt, f0, tinterval, args = (params,))
#print f0
#print f[0]
#print f[1]

# %%
# Analytical solution
a = (f2 - f1) / np.log(R2/R1)
b = (f2 + f1 - (a*np.log(R2*R1))) / 2

fanalytical = a*np.log(r) + b

# %%
# Difference between analytical and numerical solutions

difference = (abs(f[1] - fanalytical) / fanalytical) * 100
prcnt_diff = np.mean(difference)
print prcnt_diff
# Out:
# 0.640014467842

# %%
plt.figure()
plt.plot(r,f[0])
plt.plot(r,f[1],'+')
plt.plot(r,fanalytical)
plt.legend(['initial','final', 'analytical'])
plt.grid('on')
# Out:
# <img src="data:image/png;base64,...">

# %%
dummy = dfdt(f0,0,params)
dummy
# Out:
# array([  1.20086420e+02,   3.05031447e-01,   2.81159420e-01,
#          2.60752688e-01,   2.43107769e-01,   2.27699531e-01,
#          2.14128035e-01,   2.02083333e-01,   1.91321499e-01,
#          1.81647940e-01,   1.72905526e-01,   1.64965986e-01,
#          1.57723577e-01,   1.51090343e-01,   1.44992526e-01,
#          1.39367816e-01,   1.34163209e-01,   1.29333333e-01,
#          1.24839125e-01,   1.20646766e-01,   1.16726835e-01,
#          1.13053613e-01,   1.09604520e-01,   1.06359649e-01,
#          1.03301384e-01,   1.00414079e-01,   9.76837865e-02,
#          9.50980392e-02,   9.26456543e-02,   9.03165736e-02,
#          8.81017257e-02,   8.59929078e-02,   8.39826840e-02,
#          8.20642978e-02,   8.02315964e-02,   7.84789644e-02,
#          7.68012668e-02,   7.51937984e-02,   7.36522399e-02,
#          7.21726190e-02,   7.07512764e-02,   6.93848355e-02,
#          6.80701754e-02,   6.68044077e-02,   6.55848546e-02,
#          6.44090305e-02,   6.32746249e-02,   6.21794872e-02,
#          6.11216131e-02,   6.00991326e-02,   5.91102986e-02,
#          5.81534772e-02,   5.72271386e-02,   5.63298490e-02,
#          5.54602630e-02,   5.46171171e-02,   5.37992235e-02,
#          5.30054645e-02,   5.22347873e-02,   5.14861996e-02,
#          5.07587650e-02,   5.00515996e-02,   4.93638677e-02,
#          4.86947791e-02,   4.80435859e-02,   4.74095797e-02,
#          4.67920888e-02,   4.61904762e-02,   4.56041373e-02,
#          4.50324977e-02,   4.44750115e-02,   4.39311594e-02,
#          4.34004474e-02,   4.28824050e-02,   4.23765837e-02,
#          4.18825561e-02,   4.13999146e-02,   4.09282700e-02,
#          4.04672507e-02,   4.00165017e-02,   3.95756834e-02,
#          3.91444713e-02,   3.87225549e-02,   3.83096367e-02,
#          3.79054318e-02,   3.75096674e-02,   3.71220819e-02,
#          3.67424242e-02,   3.63704537e-02,   3.60059391e-02,
#         2.03883495,  2.04854369,  2.05825243,  2.06796117,  2.0776699 ,
#         2.08737864,  2.09708738,  2.10679612,  2.11650485,  2.12621359,
#         2.13592233,  2.14563107,  2.15533981,  2.16504854,  2.17475728,
#         2.18446602,  2.19417476,  2.2038835 ,  2.21359223,  2.22330097,
#         2.23300971,  2.24271845,  2.25242718,  2.26213592,  2.27184466,
#         2.2815534 ,  2.29126214,  2.30097087,  2.31067961,  2.32038835,
#         2.33009709,  2.33980583,  2.34951456,  2.3592233 ,  2.36893204,
#         2.37864078,  2.38834951,  2.39805825,  2.40776699,  2.41747573,
#         2.42718447,  2.4368932 ,  2.44660194,  2.45631068,  2.46601942,
#         2.47572816,  2.48543689,  2.49514563,  2.50485437,  2.51456311,
#         2.52427184,  2.53398058,  2.54368932,  2.55339806,  2.5631068 ,
#         2.57281553,  2.58252427,  2.59223301,  2.60194175,  2.61165049,
#         2.62135922,  2.63106796,  2.6407767 ,  2.65048544,  2.66019417,
#         2.66990291,  2.67961165,  2.68932039,  2.69902913,  2.70873786,
#         2.7184466 ,  2.72815534,  2.73786408,  2.74757282,  2.75728155,
#         2.76699029,  2.77669903,  2.78640777,  2.7961165 ,  2.80582524,
#         2.81553398,  2.82524272,  2.83495146,  2.84466019,  2.85436893,
#         2.86407767,  2.87378641,  2.88349515,  2.89320388,  2.90291262,
#         2.91262136,  2.9223301 ,  2.93203883,  2.94174757,  2.95145631,
#         2.96116505,  2.97087379,  2.98058252,  2.99029126,  3.        ])

# %%
np.append(f0,20)
# Out:
# array([  0.        ,   0.03092784,   0.06185567,   0.09278351,
#          0.12371134,   0.15463918,   0.18556701,   0.21649485,
#          0.24742268,   0.27835052,   0.30927835,   0.34020619,
#          0.37113402,   0.40206186,   0.43298969,   0.46391753,
#          0.49484536,   0.5257732 ,   0.55670103,   0.58762887,
#          0.6185567 ,   0.64948454,   0.68041237,   0.71134021,
#          0.74226804,   0.77319588,   0.80412371,   0.83505155,
#          0.86597938,   0.89690722,   0.92783505,   0.95876289,
#          0.98969072,   1.02061856,   1.05154639,   1.08247423,
#          1.11340206,   1.1443299 ,   1.17525773,   1.20618557,
#          1.2371134 ,   1.26804124,   1.29896907,   1.32989691,
#          1.36082474,   1.39175258,   1.42268041,   1.45360825,
#          1.48453608,   1.51546392,   1.54639175,   1.57731959,
#          1.60824742,   1.63917526,   1.67010309,   1.70103093,
#          1.73195876,   1.7628866 ,   1.79381443,   1.82474227,
#          1.8556701 ,   1.88659794,   1.91752577,   1.94845361,
#          1.97938144,   2.01030928,   2.04123711,   2.07216495,
#          2.10309278,   2.13402062,   2.16494845,   2.19587629,
#          2.22680412,   2.25773196,   2.28865979,   2.31958763,
#          2.35051546,   2.3814433 ,   2.41237113,   2.44329897,
#          2.4742268 ,   2.50515464,   2.53608247,   2.56701031,
#          2.59793814,   2.62886598,   2.65979381,   2.69072165,
#          2.72164948,   2.75257732,   2.78350515,   2.81443299,
#          2.84536082,   2.87628866,   2.90721649,   2.93814433,
#          2.96907216,   3.        ,  20.        ])

# %%
np.append(0,f0,1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-05d06526d7d5> in <module>()
# ----> 1 np.append(0,f0,1)
#
# //anaconda/lib/python2.7/site-packages/numpy/lib/function_base.pyc in append(arr, values, axis)
#    4584         values = ravel(values)
#    4585         axis = arr.ndim-1
# -> 4586     return concatenate((arr, values), axis=axis)
#    4587
#
# ValueError: zero-dimensional arrays cannot be concatenated
