# %%
import numpy as np
import random as rn
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
x = np.linspace(0,1.0,9); print x
# Out:
# [ 0.     0.125  0.25   0.375  0.5    0.625  0.75   0.875  1.   ]

# %%
dx = x[1]-x[0]; print dx
# Out:
# 0.125

# %%
D = 1.0

# %%
dt = dx**2/2/D / 10; print dt
nt = 10 # Number of time steps
t = dt*nt; print t
# Out:
# 0.00078125
# 0.0078125

# %%
C = (dt * D) / (dx**2); print C # For constants in "propagate" function
# Out:
# 0.05

# %%
# Starting f(t,x) as 2-D array of random numbers; pseudo: f[time][x]

f = np.array([[rn.random() for i in range(len(x))] for j in range(int(t/dt))]); print f;
# Out:
# [[ 0.50161462  0.1965252   0.40859119  0.8486505   0.56471558  0.69771512
#    0.43288115  0.70794682  0.91304415]
#  [ 0.91414348  0.25383125  0.86571293  0.17292174  0.19599473  0.07615529
#    0.81475908  0.49349749  0.32880083]
#  [ 0.75523476  0.25133091  0.54670558  0.96732847  0.59572831  0.41494417
#    0.71333425  0.28384436  0.23609518]
#  [ 0.52190785  0.94083307  0.86358349  0.80962386  0.57988783  0.92402368
#    0.56663624  0.29082866  0.06294126]
#  [ 0.51640514  0.09716674  0.36693445  0.79137317  0.74794872  0.4412047
#    0.44455795  0.6295872   0.8843119 ]
#  [ 0.91967252  0.92897359  0.02971101  0.87329941  0.5509735   0.82394065
#    0.84879419  0.03857078  0.79702969]
#  [ 0.63889236  0.14740262  0.30357637  0.75736669  0.73795042  0.84530778
#    0.60123954  0.12328392  0.14161979]
#  [ 0.97369459  0.29664784  0.54358712  0.79097836  0.84631335  0.57186831
#    0.12346725  0.41694306  0.28414129]
#  [ 0.14557555  0.38801945  0.93827747  0.18340444  0.46185798  0.61456818
#    0.59459251  0.88538065  0.35663616]
#  [ 0.18116109  0.66339582  0.47102624  0.28121726  0.06075407  0.10138706
#    0.28323061  0.92497925  0.68597567]]

# %%
# Function that iterates diffusion values through number of time steps, could probably be more efficient
def propagate(f,nt):
    for n in range(0, nt) :
        for k in range(0, len(x)): 
            
            if n == 0: # First time step needs some special treatment
                f_i = f[n][k] # Stores f at each space step before any propagation
                if k == 0:
                    f[n][k] = C * ( f[n-1][len(x)-1] - 2*f[n-1][k] + f[n-1][k+1] ) + f_i

                elif k == (len(x) - 1):
                    f[n][k] = C * ( f[n-1][k-1] - 2*f[n-1][k] + f[n-1][0] ) + f_i

                else:
                    f[n][k] = C * ( f[n-1][k-1] - 2*f[n-1][k] + f[n-1][k+1] ) + f_i
                        
            else:
                if k == 0:
                    f[n][k] = C * ( f[n-1][len(x)-1] - 2*f[n-1][k] + f[n-1][k+1] ) + f[n-1][k]

                elif k == (len(x) - 1):
                    f[n][k] = C * ( f[n-1][k-1] - 2*f[n-1][k] + f[n-1][0] ) + f[n-1][k]

                else:
                    f[n][k] = C * ( f[n-1][k-1] - 2*f[n-1][k] + f[n-1][k+1] ) + f[n-1][k]
                
    print f
    return f

# %%
propagate(f,nt)
# Out:
# [[ 0.55096708  0.16279498  0.40871922  0.84711779  0.57777039  0.70477565
#    0.4558764   0.66390921  0.8997536 ]
#  [ 0.54899781  0.1944998   0.41834294  0.81173049  0.59758802  0.68598042
#    0.47872301  0.66529979  0.87052206]
#  [ 0.54734912  0.22341686  0.42682016  0.78135399  0.61271476  0.67119793
#    0.49841472  0.66623206  0.84418473]
#  [ 0.54599429  0.24978364  0.43437669  0.75519534  0.62407088  0.65963461
#    0.51544474  0.66673883  0.82044532]
#  [ 0.5449063   0.27382382  0.44118797  0.73259818  0.63240529  0.65064693
#    0.53021894  0.66685945  0.79903744]
#  [ 0.54405874  0.29574615  0.44739027  0.71301803  0.63832702  0.64371345
#    0.54307237  0.66663632  0.77972199]
#  [ 0.54342627  0.31574399  0.45308945  0.69600209  0.64233089  0.63841208
#    0.55428262  0.66611241  0.76228454]
#  [ 0.54298507  0.33399538  0.45836781  0.6811729   0.64481851  0.63440154
#    0.56408058  0.66532953  0.74653302]
#  [ 0.54271298  0.35066348  0.46328944  0.66821492  0.64611538  0.63140634
#    0.57265908  0.66432725  0.73229545]
#  [ 0.54258963  0.36589725  0.46790442  0.65686367  0.64648491  0.62920443
#    0.58017985  0.66314225  0.71941791]]
# array([[ 0.55096708,  0.16279498,  0.40871922,  0.84711779,  0.57777039,
#          0.70477565,  0.4558764 ,  0.66390921,  0.8997536 ],
#        [ 0.54899781,  0.1944998 ,  0.41834294,  0.81173049,  0.59758802,
#          0.68598042,  0.47872301,  0.66529979,  0.87052206],
#        [ 0.54734912,  0.22341686,  0.42682016,  0.78135399,  0.61271476,
#          0.67119793,  0.49841472,  0.66623206,  0.84418473],
#        [ 0.54599429,  0.24978364,  0.43437669,  0.75519534,  0.62407088,
#          0.65963461,  0.51544474,  0.66673883,  0.82044532],
#        [ 0.5449063 ,  0.27382382,  0.44118797,  0.73259818,  0.63240529,
#          0.65064693,  0.53021894,  0.66685945,  0.79903744],
#        [ 0.54405874,  0.29574615,  0.44739027,  0.71301803,  0.63832702,
#          0.64371345,  0.54307237,  0.66663632,  0.77972199],
#        [ 0.54342627,  0.31574399,  0.45308945,  0.69600209,  0.64233089,
#          0.63841208,  0.55428262,  0.66611241,  0.76228454],
#        [ 0.54298507,  0.33399538,  0.45836781,  0.6811729 ,  0.64481851,
#          0.63440154,  0.56408058,  0.66532953,  0.74653302],
#        [ 0.54271298,  0.35066348,  0.46328944,  0.66821492,  0.64611538,
#          0.63140634,  0.57265908,  0.66432725,  0.73229545],
#        [ 0.54258963,  0.36589725,  0.46790442,  0.65686367,  0.64648491,
#          0.62920443,  0.58017985,  0.66314225,  0.71941791]])

# %%
whos
# Out:
# Variable    Type        Data/Info
# ---------------------------------
# C           float64     0.05
# D           float       1.0
# dt          float64     0.00078125
# dx          float64     0.125
# f           ndarray     10x9: 90 elems, type `float64`, 720 bytes
# i           int         8
# j           int         9
# np          module      <module 'numpy' from '/Us<...>ages/numpy/__init__.pyc'>
# nt          int         10
# plt         module      <module 'matplotlib.pyplo<...>s/matplotlib/pyplot.pyc'>
# propagate   function    <function propagate at 0x108a88398>
# rn          module      <module 'random' from '/U<...>ib/python2.7/random.pyc'>
# t           float64     0.0078125
# x           ndarray     9: 9 elems, type `float64`, 72 bytes

# %%
# This plots the initial and last entries in f
plt.plot(x,f[0])
plt.plot(x,f[-1])
# Out:
# <img src="data:image/png;base64,...">
